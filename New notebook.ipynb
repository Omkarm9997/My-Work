# %%
import pandas as pd

# %%
house_price = pd.read_csv("/data/notebook_files/AB_US_2020.csv")
house_price.head(5)
# Out:
# /opt/python/envs/default/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>host_id</th>
#       <th>host_name</th>
#       <th>neighbourhood_group</th>
#       <th>neighbourhood</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>room_type</th>
#       <th>price</th>
#       <th>minimum_nights</th>
#       <th>number_of_reviews</th>
#       <th>last_review</th>
# ...

# %%
house_price.drop(axis=1, columns=["neighbourhood_group","city"], inplace=True)

# %%
house_price.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>host_id</th>
#       <th>host_name</th>
#       <th>neighbourhood</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>room_type</th>
#       <th>price</th>
#       <th>minimum_nights</th>
#       <th>number_of_reviews</th>
#       <th>last_review</th>
#       <th>reviews_per_month</th>
#       <th>calculated_host_listings_count</th>
#       <th>availability_365</th>
#       <th>city</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>38585</td>
#       <td>Charming Victorian home - twin beds + breakfast</td>
# ...

# %%
house_price.drop(2, axis=0)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>host_id</th>
#       <th>host_name</th>
#       <th>neighbourhood</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>room_type</th>
#       <th>price</th>
#       <th>minimum_nights</th>
#       <th>number_of_reviews</th>
#       <th>last_review</th>
#       <th>reviews_per_month</th>
#       <th>calculated_host_listings_count</th>
#       <th>availability_365</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>38585</td>
#       <td>Charming Victorian home - twin beds + breakfast</td>
#       <td>165529</td>
# ...

# %%
house_price.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>host_id</th>
#       <th>host_name</th>
#       <th>neighbourhood</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>room_type</th>
#       <th>price</th>
#       <th>minimum_nights</th>
#       <th>number_of_reviews</th>
#       <th>last_review</th>
#       <th>reviews_per_month</th>
#       <th>calculated_host_listings_count</th>
#       <th>availability_365</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>38585</td>
#       <td>Charming Victorian home - twin beds + breakfast</td>
#       <td>165529</td>
# ...

# %%
import warningswarnings.filterwarnings("ignore")TO REMOVE THE WARNINGS
house_price["name"][2] = "ASDDFGH"
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
# SyntaxError: invalid syntax

# %%
iris = pd.read_csv("/data/notebook_files/Iris.csv")
iris.tail(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>SepalLengthCm</th>
#       <th>SepalWidthCm</th>
#       <th>PetalLengthCm</th>
#       <th>PetalWidthCm</th>
#       <th>Species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>145</th>
#       <td>146</td>
#       <td>6.7</td>
#       <td>3.0</td>
#       <td>5.2</td>
#       <td>2.3</td>
#       <td>Iris-virginica</td>
#     </tr>
#     <tr>
#       <th>146</th>
#       <td>147</td>
#       <td>6.3</td>
#       <td>2.5</td>
#       <td>5.0</td>
#       <td>1.9</td>
#       <td>Iris-virginica</td>
#     </tr>
#     <tr>
#       <th>147</th>
#       <td>148</td>
# ...

# %%
iris.dtypes
# Out:
# <pre>Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object</pre>

# %%
iris.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>SepalLengthCm</th>
#       <th>SepalWidthCm</th>
#       <th>PetalLengthCm</th>
#       <th>PetalWidthCm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>150.000000</td>
#       <td>150.000000</td>
#       <td>150.000000</td>
#       <td>150.000000</td>
#       <td>150.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>75.500000</td>
#       <td>5.843333</td>
#       <td>3.054000</td>
#       <td>3.758667</td>
#       <td>1.198667</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>43.445368</td>
#       <td>0.828066</td>
# ...

# %%
my_df = pd.DataFrame([[10, 20, 30, 40, "Avatar World"]], columns=["sepal_length", "sepal_width","petal_length", "petal_width", "species"])

# %%
iris_data = iris.append(my_df,ignore_index=True)
iris_data.tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>SepalLengthCm</th>
#       <th>SepalWidthCm</th>
#       <th>PetalLengthCm</th>
#       <th>PetalWidthCm</th>
#       <th>Species</th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>146</th>
#       <td>147.0</td>
#       <td>6.3</td>
#       <td>2.5</td>
#       <td>5.0</td>
#       <td>1.9</td>
#       <td>Iris-virginica</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
# ...

# %%
iris_data.sort_index(inplace=True) # used to sort or reset index of dataset...

# %%
iris_data.tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>SepalLengthCm</th>
#       <th>SepalWidthCm</th>
#       <th>PetalLengthCm</th>
#       <th>PetalWidthCm</th>
#       <th>Species</th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>146</th>
#       <td>147.0</td>
#       <td>6.3</td>
#       <td>2.5</td>
#       <td>5.0</td>
#       <td>1.9</td>
#       <td>Iris-virginica</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
# ...

# %%
df = iris_data.sum(axis=1)
# Out:
# <ipython-input-52-ec26b39ad7a5>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df = iris_data.sum(axis=1)

# %%
iris_data['Sum'] = iris_data.sum(axis=1)
print(iris_data)
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0            5.1           3.5            1.4           0.2
# 1      2.0            4.9           3.0            1.4           0.2
# 2      3.0            4.7           3.2            1.3           0.2
# 3      4.0            4.6           3.1            1.5           0.2
# 4      5.0            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
# 150    NaN            NaN           NaN            NaN           NaN
#
#             Species  sepal_length  sepal_width  petal_length  petal_width  \
# ...

# %%
df1 = pd.DataFrame(iris_data)
df1.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>SepalLengthCm</th>
#       <th>SepalWidthCm</th>
#       <th>PetalLengthCm</th>
#       <th>PetalWidthCm</th>
#       <th>Species</th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species</th>
#       <th>Sum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
# ...

# %%
iris_data.append(iris_data.sum(),ignore_index=True)
# Out:
# <ipython-input-61-a6d6399842ae>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   iris_data.append(iris_data.sum(),ignore_index=True)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>SepalLengthCm</th>
#       <th>SepalWidthCm</th>
#       <th>PetalLengthCm</th>
#       <th>PetalWidthCm</th>
#       <th>Species</th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species</th>
# ...

# %%
iris_data.nunique() #to get unique values of overall dataset...
# Out:
# <pre>Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# sepal_length       1
# sepal_width        1
# petal_length       1
# petal_width        1
# species            1
# Sum              148
# dtype: int64</pre>

# %%
iris_data["Species"].nunique()
# Out:
# 3

# %%
iris1 =pd.read_csv("/data/notebook_files/iris (1).csv") 
iris1.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>setosa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.9</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>setosa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.7</td>
#       <td>3.2</td>
#       <td>1.3</td>
#       <td>0.2</td>
#       <td>setosa</td>
#     </tr>
# ...

# %%
iris2 = iris1.drop(axis = 1, columns = ["species"])
iris3 = iris2.copy()
iris4 = iris2 /iris3
extracted_col = iris1["species"]
iris4 = iris4.join(extracted_col)
#print(iris4)
new_iris = pd.DataFrame(iris4)
print(new_iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             1.0          1.0           1.0          1.0     setosa
# 1             1.0          1.0           1.0          1.0     setosa
# 2             1.0          1.0           1.0          1.0     setosa
# 3             1.0          1.0           1.0          1.0     setosa
# 4             1.0          1.0           1.0          1.0     setosa
# ..            ...          ...           ...          ...        ...
# 145           1.0          1.0           1.0          1.0  virginica
# 146           1.0          1.0           1.0          1.0  virginica
# 147           1.0          1.0           1.0          1.0  virginica
# 148           1.0          1.0           1.0          1.0  virginica
# 149           1.0          1.0           1.0          1.0  virginica
#
# [150 rows x 5 columns]
