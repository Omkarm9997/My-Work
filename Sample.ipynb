# %% [markdown]
# ##Data Cleaning
# 1. Removing/Filling empty cells
# 2. Cleaning Wrong formmat
# 3. Cleaning wrong data
# 4. Cleaning Duplicates

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Creating our own dataframe

# %%
my_temp_df = {
    "Names": ["Harry", "Ron", "Heromine"],
    "USN": ["123","", "0055"],
    "Att": [12, 45,"89"]
}

my_df = pd.DataFrame(my_temp_df)

# %%
my_df.replace('',value=np.NaN, inplace=True)
my_df.head()
# Out:
#       Names   USN Att
# 0     Harry   123  12
# 1       Ron   NaN  45
# 2  Heromine  0055  89

# %%
my_df.dropna(inplace=True)
my_df.head()
# Out:
#       Names   USN Att
# 0     Harry   123  12
# 2  Heromine  0055  89

# %%
my_df.reset_index(drop=True, inplace=True)

# %%
my_df.head()
# Out:
#       Names   USN Att
# 0     Harry   123  12
# 1  Heromine  0055  89

# %%
my_df["Att"] = my_df["Att"].apply(pd.to_numeric)
my_df["Att"].mean()
# Out:
# 50.5

# %%
my_df.mean()
# Out:
# <ipython-input-65-9b790e678502>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   my_df.mean()
# USN    615027.5
# Att        50.5
# dtype: float64

# %%
my_temp_df = {
    "Names": ["Harry", "Ron", "Heromine"],
    "USN": ["11","21", "41",],
    "Att": [1, 1, ""]
}

my_df = pd.DataFrame(my_temp_df)

# %%
my_df.head()
# Out:
#       Names USN  Att
# 0     Harry   1    1
# 1       Ron   1    1
# 2  Heromine   1    1

# %%
my_df.mean()
# Out:
# <ipython-input-102-9b790e678502>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   my_df.mean()
# USN    37.0
# Att     1.0
# dtype: float64

# %% [markdown]
# # Working with mock data

# %%
mock_data = pd.read_csv("MOCK_DATA.csv")

# %%
mock_data.head(10)
# Out:
#                  Name  USN  Att
# 0       Ettie Ridolfi    1   86
# 1       Gayla Swadlin    3   69
# 2  Nicholas Fairbrass    5   55
# 3         Hailee Thor   93   64
# 4        Nara Sitwell   46    7
# 5        Mayne Mayhew   69   53
# 6      Hatti McClancy   12   26
# 7   Halimeda Marquiss   22   41
# 8     Felix O'Noulane   97   37
# 9     Madelin Robinet   58   13

# %%
for i in mock_data["USN"]:
  if i%2==0:
    mock_data["USN"].replace(i, np.NaN, inplace=True)

# %%
mock_data.head(10)
# Out:
#                  Name   USN  Att
# 0       Ettie Ridolfi   1.0   86
# 1       Gayla Swadlin   3.0   69
# 2  Nicholas Fairbrass   5.0   55
# 3         Hailee Thor  93.0   64
# 4        Nara Sitwell   NaN    7
# 5        Mayne Mayhew  69.0   53
# 6      Hatti McClancy   NaN   26
# 7   Halimeda Marquiss   NaN   41
# 8     Felix O'Noulane  97.0   37
# 9     Madelin Robinet   NaN   13

# %%
mock_data = pd.read_csv("MOCK_DATA.csv")

# %%
mock_data.head()
# Out:
#                  Name  USN  Att
# 0       Ettie Ridolfi    1   86
# 1       Gayla Swadlin    3   69
# 2  Nicholas Fairbrass    5   55
# 3         Hailee Thor   93   64
# 4        Nara Sitwell   46    7

# %%
mock_data["USN"][mock_data["USN"] % 2==0] = np.NaN
# Out:
# <ipython-input-119-453b6d2d66cc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mock_data["USN"][mock_data["USN"] % 2==0] = np.NaN

# %%
mock_data.head(20)
# Out:
#                   Name   USN  Att
# 0        Ettie Ridolfi   1.0   86
# 1        Gayla Swadlin   3.0   69
# 2   Nicholas Fairbrass   5.0   55
# 3          Hailee Thor  93.0   64
# 4         Nara Sitwell   NaN    7
# 5         Mayne Mayhew  69.0   53
# 6       Hatti McClancy   NaN   26
# 7    Halimeda Marquiss   NaN   41
# 8      Felix O'Noulane  97.0   37
# 9      Madelin Robinet   NaN   13
# 10   Augustine Kemster  11.0   38
# 11      Rivkah Longina  85.0   59
# 12          Zed Sturte  59.0   40
# 13         Cliff Aslin  41.0   85
# 14       Yuma Hayfield   NaN   44
# 15        Lyn Scogings  45.0    9
# 16     Jorrie Parzizek   NaN   29
# 17    Connor Graveston   NaN   96
# 18       Iolande Blaze   NaN   98
# 19       Keefer Brusle   NaN   31

# %%
mock_data = pd.read_csv("MOCK_DATA.csv")

# %%
mock_data.head(10)
# Out:
#                  Name  USN  Att
# 0       Ettie Ridolfi    1   86
# 1       Gayla Swadlin    3   69
# 2  Nicholas Fairbrass    5   55
# 3         Hailee Thor   93   64
# 4        Nara Sitwell   46    7
# 5        Mayne Mayhew   69   53
# 6      Hatti McClancy   12   26
# 7   Halimeda Marquiss   22   41
# 8     Felix O'Noulane   97   37
# 9     Madelin Robinet   58   13

# %%
mock_data["USN"][mock_data["USN"] % 2 == 0] = np.NaN
# Out:
# <ipython-input-138-c105d0aa8a41>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mock_data["USN"][mock_data["USN"] % 2 == 0] = np.NaN

# %%
mock_data.head(25)
# Out:
#                   Name   USN  Att
# 0        Ettie Ridolfi   1.0   86
# 1        Gayla Swadlin   3.0   69
# 2   Nicholas Fairbrass   5.0   55
# 3          Hailee Thor  93.0   64
# 4         Nara Sitwell   NaN    7
# 5         Mayne Mayhew  69.0   53
# 6       Hatti McClancy   NaN   26
# 7    Halimeda Marquiss   NaN   41
# 8      Felix O'Noulane  97.0   37
# 9      Madelin Robinet   NaN   13
# 10   Augustine Kemster  11.0   38
# 11      Rivkah Longina  85.0   59
# 12          Zed Sturte  59.0   40
# 13         Cliff Aslin  41.0   85
# 14       Yuma Hayfield   NaN   44
# 15        Lyn Scogings  45.0    9
# 16     Jorrie Parzizek   NaN   29
# 17    Connor Graveston   NaN   96
# 18       Iolande Blaze   NaN   98
# 19       Keefer Brusle   NaN   31
# 20       Hanna Eshelby  25.0   18
# 21        Sergio Twist   NaN   97
# 22    Wendi Pauncefort  83.0   58
# 23    Courtney Stannus   NaN   28
# 24    Sergei Giannotti   NaN   65

# %%
mock_data.dropna(inplace=True)

# %%
mock_data.reset_index(drop=True)
# Out:
#                                 Name   USN  Att
# 0                      Ettie Ridolfi   1.0   86
# 1                      Gayla Swadlin   3.0   69
# 2                 Nicholas Fairbrass   5.0   55
# 3                        Hailee Thor  93.0   64
# 4                       Mayne Mayhew  69.0   53
# ..                               ...   ...  ...
# 268                   Sheila Beslier  93.0   74
# 269  Marge Le Breton De La Vieuville  91.0   70
# 270                    Hammad Druhan  89.0   10
# 271                  Karly Coneybeer  63.0   27
# 272                Deedee Konzelmann  19.0   30
#
# [273 rows x 3 columns]

# %% [markdown]
# # Working with Country and Drug Names

# %%
drug_df = pd.read_csv("country.csv")

# %%
drug_df.head()
# Out:
#            Drug Name      Country  Avearage Consumption
# 0            Pumpkin         Peru                59.632
# 1             Oxygen       Russia                56.659
# 2  enoxaparin sodium  Philippines                 9.722
# 3      CHLOROXYLENOL     Portugal                28.985
# 4        Dimethicone     Colombia                61.980

# %%
unique_countries = drug_df["Country"].unique()
unique_countries
# Out:
# array(['Peru', 'Russia', 'Philippines', 'Portugal', 'Colombia',
#        'South Korea', 'China', 'Cyprus', 'France', 'Libya', 'Serbia',
#        'Uganda', 'Togo', 'Indonesia', 'Azerbaijan', 'Armenia',
#        'New Zealand', 'Albania', 'Panama', 'Canada', 'Thailand', 'Poland',
#        'Palestinian Territory', 'Greece', 'Mexico', 'Yemen', 'Angola',
#        'Brazil', 'United Kingdom', 'Ukraine', 'Kazakhstan', 'Japan',
#        'Argentina', 'Sweden', 'El Salvador', 'Czech Republic', 'Pakistan',
#        'Cuba', 'Kosovo', 'Paraguay', 'Tanzania', 'Mali', 'Nigeria',
#        'Costa Rica', 'Finland', 'Afghanistan', 'Morocco', 'Rwanda',
#        'Norway', 'Latvia', 'Equatorial Guinea', 'Guatemala', 'Tunisia',
#        'Honduras', 'Iran', 'Lithuania', 'Brunei', 'Ireland',
#        'Bosnia and Herzegovina', 'Ecuador', 'United States', 'Estonia',
#        'Malawi', 'Syria', 'Venezuela', 'Haiti', 'Dominican Republic',
#        'Chad', 'Bahamas', 'Uzbekistan', 'Slovenia', 'Mauritius', 'Nepal',
# ...

# %%
df_list = []
for x, i in enumerate(unique_countries):
  state = drug_df[drug_df['Country'] == i]
  df_list.append(state)

df_list[3].head(10)
# Out:
#                                              Drug Name   Country  \
# 3                                        CHLOROXYLENOL  Portugal
# 8    Aconitum napellus, Antimonium tartaricum, Bell...  Portugal
# 21                                           RIFAXIMIN  Portugal
# 78                                      Spironolactone  Portugal
# 174                            quinapril hydrochloride  Portugal
# 214                 Urea Cream with Moisturizing Cream  Portugal
# 215                            Bupropion Hydrochloride  Portugal
# 238           Aluminum Zirconium Tetrachlorohydrex GLY  Portugal
# 265  Agnus, Aralia quinquefolia, Baryta carb., Berb...  Portugal
# 268                             KETOROLAC TROMETHAMINE  Portugal
#
#      Avearage Consumption
# 3                  28.985
# 8                  21.814
# 21                 43.789
# 78                 72.592
# 174                81.249
# 214                88.670
# 215                84.084
# 238                54.228
# ...

# %% [markdown]
# # Junee's Solution

# %%
drug_data = pd.read_csv('country.csv')
drug_data.head(5)
df = []
unique_country = drug_data["Country"].unique()
for key, value in enumerate(unique_countries):
    country_value = drug_data[drug_data["Country"] == value]
    df.append(country_value)
  
df[0].head()
# Out:
#                                              Drug Name Country  \
# 0                                              Pumpkin    Peru
# 33                                       Levetiracetam    Peru
# 98                 telmisartan and hydrochlorothiazide    Peru
# 171  Avobenzone, Homosalate, Octisalate, Octocrylen...    Peru
# 199                                         Furosemide    Peru
#
#      Avearage Consumption
# 0                  59.632
# 33                 50.518
# 98                 37.114
# 171                81.479
# 199                22.969

# %% [markdown]
# # Find the most common Drug in
# 1. Find the most common drug in each country
# 2. create a new dataframe which contains 3 columns i.e : Country Name, Most common drug, Consumption of the drug

# %%
drug_data = pd.read_csv('country.csv')

# %%
print(type(drug_data.max()))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(drug_data["Avearage Consumption"]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
drug_data.groupby("Avearage Consumption").last()
# Out:
#                                                               Drug Name  \
# Avearage Consumption
# 1.046                                                         Acyclovir
# 1.258                                                   Naproxen Sodium
# 1.380                                                          Glycerin
# 1.468                 Antimoniom crudum, Baptisia tinctoria, Caustic...
# 1.536                                   Titanium Dioxide and Zinc Oxide
# ...                                                                 ...
# 99.471                                                CUPRUM METALLICUM
# 99.511                                            Benzalkonium chloride
# 99.657                Agnus, Aralia quinquefolia, Baryta carb., Berb...
# 99.772                                                           OXYGEN
# 99.962                                          Citalopram Hydrobromide
#
#                         Country
# Avearage Consumption
# ...

# %%
data_df = pd.read_csv("country.csv")
result  = data_df.groupby(["Country"])["Avearage Consumption"].transform(max) == data_df["Avearage Consumption"]
data_df[result]["Country"]
# Out:
# 5       South Korea
# 9            Cyprus
# 11            Libya
# 14             Togo
# 18          Armenia
#            ...
# 945         Albania
# 946    South Africa
# 953      Madagascar
# 970          Belize
# 999           Benin
# Name: Country, Length: 115, dtype: object

# %%
drug_data = pd.read_csv('country.csv')

# %%
unique_countries = drug_data["Country"].unique()
unique_countries
# Out:
# array(['Peru', 'Russia', 'Philippines', 'Portugal', 'Colombia',
#        'South Korea', 'China', 'Cyprus', 'France', 'Libya', 'Serbia',
#        'Uganda', 'Togo', 'Indonesia', 'Azerbaijan', 'Armenia',
#        'New Zealand', 'Albania', 'Panama', 'Canada', 'Thailand', 'Poland',
#        'Palestinian Territory', 'Greece', 'Mexico', 'Yemen', 'Angola',
#        'Brazil', 'United Kingdom', 'Ukraine', 'Kazakhstan', 'Japan',
#        'Argentina', 'Sweden', 'El Salvador', 'Czech Republic', 'Pakistan',
#        'Cuba', 'Kosovo', 'Paraguay', 'Tanzania', 'Mali', 'Nigeria',
#        'Costa Rica', 'Finland', 'Afghanistan', 'Morocco', 'Rwanda',
#        'Norway', 'Latvia', 'Equatorial Guinea', 'Guatemala', 'Tunisia',
#        'Honduras', 'Iran', 'Lithuania', 'Brunei', 'Ireland',
#        'Bosnia and Herzegovina', 'Ecuador', 'United States', 'Estonia',
#        'Malawi', 'Syria', 'Venezuela', 'Haiti', 'Dominican Republic',
#        'Chad', 'Bahamas', 'Uzbekistan', 'Slovenia', 'Mauritius', 'Nepal',
# ...

# %%
df_list = []
for i in unique_countries:
  df_list.append(drug_data[drug_data["Country"] == i])
# Out:
#                                              Drug Name Country  \
# 0                                              Pumpkin    Peru
# 33                                       Levetiracetam    Peru
# 98                 telmisartan and hydrochlorothiazide    Peru
# 171  Avobenzone, Homosalate, Octisalate, Octocrylen...    Peru
# 199                                         Furosemide    Peru
#
#      Avearage Consumption
# 0                  59.632
# 33                 50.518
# 98                 37.114
# 171                81.479
# 199                22.969

# %%
max_df_list = []
for i in df_list:
  max_df_list.append(i.max())

final = pd.DataFrame(max_df_list)
final.head(20)
# Out:
#                                             Drug Name      Country  \
# 0                 telmisartan and hydrochlorothiazide         Peru
# 1                                         tocilizumab       Russia
# 2                                         risperidone  Philippines
# 3                             quinapril hydrochloride     Portugal
# 4                                          zidovudine     Colombia
# 5                                           Triclosan  South Korea
# 6                                   zolpidem tartrate        China
# 7                               doxepin hydrochloride       Cyprus
# 8                                        escitalopram       France
# 9   AVOBENZONE HOMOSALATE OCTISALATE OCTOCRYLENE O...        Libya
# 10                           tizanidine hydrochloride       Serbia
# 11                                   TITANIUM DIOXIDE       Uganda
# 12                                 Octreotide acetate         Togo
# ...
